# %%
# Name a more iconic trio... I'll wait…
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# get data for gold coin 

# dollar 
gold_price = 1500
colletralized_percentage = 80
rebuys = 100
range_rebuys = range(1,rebuys+1)
nan_array = np.full(rebuys, np.nan)

# %%
df = pd.DataFrame.from_dict(dict([('# gold coins', range_rebuys), ('own money invested', nan_array), ('loaned money', nan_array), ('price of assets', nan_array), ('gold price', nan_array)]), dtype=np.double)

df = df.astype({'# gold coins': int})

df.set_index('# gold coins', inplace=True, drop=True)
df
# Out:
#               own money invested  loaned money  price of assets  gold price
# # gold coins
# 1                            NaN           NaN              NaN         NaN
# 2                            NaN           NaN              NaN         NaN
# 3                            NaN           NaN              NaN         NaN
# 4                            NaN           NaN              NaN         NaN
# 5                            NaN           NaN              NaN         NaN
# ...                          ...           ...              ...         ...
# 96                           NaN           NaN              NaN         NaN
# 97                           NaN           NaN              NaN         NaN
# 98                           NaN           NaN              NaN         NaN
# 99                           NaN           NaN              NaN         NaN
# 100                          NaN           NaN              NaN         NaN
#
# [100 rows x 4 columns]

# %%
current_assets = 0
current_money_invested = 0
current_loaned_money = 0
gold_price = 1500

for index, row in df.iterrows():
    current_money_invested += (gold_price * (100-colletralized_percentage)) / 100
    current_loaned_money += (gold_price * colletralized_percentage) / 100
    current_assets = gold_price * index

    row['own money invested'] = current_money_invested
    row['loaned money'] = current_loaned_money
    row['price of assets'] = current_assets
    

df.plot()

# %%
current_assets = 0
current_money_invested = 0
current_loaned_money = 0
gold_price = 1500

for index, row in df.iterrows():
    
    if index > 20:
        gold_price -= (gold_price / 100) * 5

    current_money_invested += (gold_price * (100-colletralized_percentage)) / 100
    current_loaned_money += (gold_price * colletralized_percentage) / 100
    current_assets = gold_price * index
    
    row['own money invested'] = current_money_invested
    row['loaned money'] = current_loaned_money
    row['price of assets'] = current_assets
    

df.plot()

# %%
current_assets = 0
current_money_invested = 0
current_loaned_money = 0
gold_price = 1500

for index, row in df.iterrows():

    if index > 20:
        gold_price += (gold_price / 100) * 5

    current_money_invested += (gold_price * (100-colletralized_percentage)) / 100
    current_loaned_money += (gold_price * colletralized_percentage) / 100
    current_assets = gold_price * index
    
    row['own money invested'] = current_money_invested
    row['loaned money'] = current_loaned_money
    row['price of assets'] = current_assets
    

df.plot()

# %%
current_assets = 0
current_money_invested = 0
current_loaned_money = 0
gold_price = 1500


# fluctuating_curve = 
time        = np.arange(0, 100, 1)
# Amplitude of the sine wave is sine of a variable like time
amplitude   = np.sin(time / 6)

# Plot a sine wave using time and amplitude obtained for the sine wave
plt.plot(time, amplitude)

# %%
current_assets = 0
current_money_invested = 0
current_loaned_money = 0
gold_price=1500

for index, row in df.iterrows():
    current_money_invested += (gold_price * (100-colletralized_percentage)) / 100
    current_loaned_money += (gold_price * colletralized_percentage) / 100
    current_assets += gold_price

    if index > 20:
        gold_price += (gold_price / 100) * 5
    
    row['own money invested'] = current_money_invested
    row['loaned money'] = current_loaned_money
    row['price of assets'] = current_assets
    

df.plot()

# %%
historical_gold_price = pd.read_csv('historical_gold_price.csv', parse_dates=True)
historical_gold_price['USD'] = historical_gold_price['USD'].astype(float)
historical_gold_price.plot()
#np.double

# %%
{‘a’: np.float64, ‘b’: np.int32, ‘c’: ‘Int64’}

# %%
current_assets = 0
current_money_invested = 0
current_loaned_money = 0
gold_price = 1500

for index, row in df.iterrows():
    gold_price_swinging = gold_price + (gold_price / 100) * 50 * amplitude[index-1]
    current_money_invested += (gold_price_swinging * (100-colletralized_percentage)) / 100
    current_loaned_money += (gold_price_swinging * colletralized_percentage) / 100
    current_assets = gold_price_swinging * index

    row['gold price'] = gold_price_swinging
    row['own money invested'] = current_money_invested
    row['loaned money'] = current_loaned_money
    row['price of assets'] = current_assets

df.plot()

# %%
https://raw.githubusercontent.com/5agado/data-science-learning/master/data%20analysis/Data%20Viz%20-%20Intro.ipynb
